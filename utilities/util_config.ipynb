# %%
# Catalog and Schema

CATALOG = "superstore"
SCHEMA_BRONZE = "bronze"
SCHEMA_SILVER = "silver"
SCHEMA_GOLD = "gold"

# Volume path (where raw CSV is uploaded)
VOLUME_PATH = f"/Volumes/{CATALOG}/{SCHEMA_BRONZE}/raw_data" # /Volumes/superstore/bronze/raw_data
RAW_FILE = f"{VOLUME_PATH}/Superstore.csv"

# Full table references
# Bronze
TBL_BRONZE_RAW = f"{CATALOG}.{SCHEMA_BRONZE}.raw_superstore"

# Silver
TBL_SILVER_ORDERS = f"{CATALOG}.{SCHEMA_SILVER}.orders"
TBL_SILVER_CUSTOMERS = f"{CATALOG}.{SCHEMA_SILVER}.customers"
TBL_SILVER_PRODUCTS = f"{CATALOG}.{SCHEMA_SILVER}.products"

# Gold - Dimensions
TBL_GOLD_DIM_CUSTOMER = f"{CATALOG}.{SCHEMA_GOLD}.dim_customer"
TBL_GOLD_DIM_PRODUCT = f"{CATALOG}.{SCHEMA_GOLD}.dim_product"
TBL_GOLD_DIM_DATE = f"{CATALOG}.{SCHEMA_GOLD}.dim_date"
TBL_GOLD_DIM_LOCATION = f"{CATALOG}.{SCHEMA_GOLD}.dim_location"
TBL_GOLD_DIM_SHIPMENT = f"{CATALOG}.{SCHEMA_GOLD}.dim_shipment"

# Gold - Fact
TBL_GOLD_FACT_ORDERS = f"{CATALOG}.{SCHEMA_GOLD}.fact_orders"

# %%
print("✅ Config loaded successfully.")
print(f"Catalog: {CATALOG}")
print(f"Bronze: {SCHEMA_BRONZE}")
print(f"Silver: {SCHEMA_SILVER}")
print(f"Gold: {SCHEMA_GOLD}")
print(f"Raw file: {RAW_FILE}")
